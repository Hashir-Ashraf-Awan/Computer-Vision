# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
img_path = "E:\\Computer Vision\\LAB\\openLAB\\road.jpg"
original = cv2.imread(img_path)

# %%
cv2.imshow("Original", original)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
original_rgb = cv2.cvtColor(original, cv2.COLOR_BGR2RGB)
H, W = original.shape[:2]
cv2.imshow("Original", original_rgb)
cv2.waitKey(0)
cv2.destroyAllWindows()
gray = cv2.cvtColor(original, cv2.COLOR_BGR2GRAY)
cv2.imshow("Original", gray)
cv2.waitKey(0)

cv2.destroyAllWindows()

# %%
#blurred = cv2.GaussianBlur(gray, (5, 5), 0)
#cv2.imshow("Blurred", blurred)
#cv2.waitKey(0)
#cv2.destroyAllWindows()

# %%
edges = cv2.Canny(gray, threshold1=50, threshold2=150)
cv2.imshow("edges", edges)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
roi_vertices = np.array([[
    (0,H),(int(W*0.4), int(H*0.6)), (int(W*0.6), int(H*0.6)), (W,H)]], dtype=np.int32)

# %%
mask = np.zeros_like(edges)
cv2.fillPoly(mask, roi_vertices, 255)
masked = cv2.bitwise_and(edges, mask)

# %%
lines = cv2.HoughLinesP(masked, 1, np.pi/180,threshold=52,minLineLength=80,maxLineGap=90)
output = original_rgb.copy()


for line in lines:
    x1, y1, x2, y2 = line[0]
    cv2.line(output, (x1, y1), (x2, y2), (255, 15, 213), 4)

# %%
plt.imshow(masked, cmap='gray')
plt.title("Edges + ROI")
plt.axis('off')
plt.figure(figsize=(14, 5))

plt.subplot(1, 3, 2)
plt.imshow(masked, cmap='gray')
plt.title("Edges + ROI")
plt.axis('off')

plt.subplot(1, 3, 3)
plt.imshow(output)
plt.title("Detected Lanes")
plt.axis('off')
# Out:
# (np.float64(-0.5), np.float64(959.5), np.float64(539.5), np.float64(-0.5))

# %%
plt.imshow(masked, cmap='gray')
plt.title("Edges + ROI")
plt.axis('off')
plt.figure(figsize=(14, 5))

plt.subplot(1, 3, 2)
plt.imshow(masked, cmap='gray')
plt.title("Edges + ROI")
plt.axis('off')

plt.subplot(1, 3, 3)
plt.imshow(output)
plt.title("Detected Lanes")
plt.axis('off')
# Out:
# (np.float64(-0.5), np.float64(953.5), np.float64(545.5), np.float64(-0.5))
